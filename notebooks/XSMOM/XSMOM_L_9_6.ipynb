# %% [markdown]
# ## Only-Long Cross-Sectional Momentum Strategy
#
# - Ranking Period: 9 months
# - Holding Period: 6 months
# - Assets in losers portfolio: 0
# - Assets in winners portfolio: 20
# - Rebalance technique: Equally-weighted

# %%
# %matplotlib inline
from datetime import datetime

import pandas as pd
import pytz
from trading_calendars import get_calendar
from zipline import run_algorithm

from strategies.momentum import Momentum

def initialize(context):
    strategy = Momentum(ranking_period=9,
                                holding_period=6,
                                momentum_gap=1,
                                losers_amount=0,
                                winners_amount=20)
    strategy.initialize(context)
    context.strategy = strategy


def rebalance(context, data):
    context.strategy.rebalance(context, data)


def analyze(context, perf: pd.DataFrame) -> None:
    context.strategy.analyze(context, perf)

# %%
start = datetime(2012, 1, 3, 7, 0, 0, tzinfo=pytz.timezone('Europe/Moscow'))
end = datetime(2018, 12, 31, 7, 0, 0, tzinfo=pytz.timezone('Europe/Moscow'))
results = run_algorithm(
    start=start,
    end=end,
    initialize=initialize,
    capital_base=1000000,
    analyze=analyze,
    bundle='database_bundle2',
    trading_calendar=get_calendar('XMOS')
)
# Out:
# Initialized strategy CSMOM_L_9_6.pickle at 0.0 seconds
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2012-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2018-12-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>83</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>2.5%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>18.9%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>3.5%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.73</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.35</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-7.3%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.14</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>-0.78</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>5.42</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.02</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-0.4%</td>
#     </tr>
#     <tr>
#       <th>Gross leverage</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Daily turnover</th>
#       <td>2.9%</td>
#     </tr>
#   </tbody>
# </table>
# /Users/germanarutunov/opt/miniconda3/envs/strategies/lib/python3.5/site-packages/numpy/core/fromnumeric.py:52: FutureWarning: 'argmin' is deprecated. Use 'idxmin' instead. The behavior of 'argmin' will be corrected to return the positional minimum in the future. Use 'series.values.argmin' to get the position of the minimum now.
#   return getattr(obj, method)(*args, **kwds)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>7.30</td>
#       <td>2012-03-05</td>
#       <td>2014-03-14</td>
#       <td>2015-02-11</td>
#       <td>768</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>3.53</td>
#       <td>2017-01-27</td>
#       <td>2017-03-09</td>
#       <td>2017-09-12</td>
#       <td>163</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>3.08</td>
#       <td>2018-10-03</td>
#       <td>2018-12-25</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.98</td>
#       <td>2015-03-04</td>
#       <td>2015-03-27</td>
#       <td>2015-08-07</td>
#       <td>113</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2.13</td>
#       <td>2018-02-27</td>
#       <td>2018-06-19</td>
#       <td>2018-10-03</td>
#       <td>157</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>0.01%</td>
#       <td>-0.55%</td>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>-0.01%</td>
#       <td>-0.49%</td>
#       <td>0.41%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.03%</td>
#       <td>-0.48%</td>
#       <td>0.46%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>-0.02%</td>
#       <td>-0.81%</td>
#       <td>0.62%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>-0.00%</td>
#       <td>-0.92%</td>
#       <td>0.86%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-1.71%</td>
#       <td>0.83%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>UNKL</th>
#       <td>2.43%</td>
#     </tr>
#     <tr>
#       <th>TGKBP</th>
#       <td>2.01%</td>
#     </tr>
#     <tr>
#       <th>IRKT</th>
#       <td>1.91%</td>
#     </tr>
#     <tr>
#       <th>MRKZ</th>
#       <td>1.61%</td>
#     </tr>
#     <tr>
#       <th>MTLRP</th>
#       <td>1.52%</td>
#     </tr>
#     <tr>
#       <th>CHMK</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>DVEC</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>SELG</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>ROLO</th>
#       <td>1.42%</td>
#     </tr>
#     <tr>
#       <th>SVAV</th>
#       <td>1.40%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>MRKY</th>
#       <td>-0.07%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>UNKL</th>
#       <td>2.43%</td>
#     </tr>
#     <tr>
#       <th>TGKBP</th>
#       <td>2.01%</td>
#     </tr>
#     <tr>
#       <th>IRKT</th>
#       <td>1.91%</td>
#     </tr>
#     <tr>
#       <th>MRKZ</th>
#       <td>1.61%</td>
#     </tr>
#     <tr>
#       <th>MTLRP</th>
#       <td>1.52%</td>
#     </tr>
#     <tr>
#       <th>CHMK</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>DVEC</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>SELG</th>
#       <td>1.43%</td>
#     </tr>
#     <tr>
#       <th>ROLO</th>
#       <td>1.42%</td>
#     </tr>
#     <tr>
#       <th>SVAV</th>
#       <td>1.40%</td>
#     </tr>
#   </tbody>
# </table>
# Finnished strategy CSMOM_L_9_6.pickle at 40.8 seconds

# %%
pd.options.display.float_format = '{:,.4f}'.format
results['algorithm_period_return'].astype(float)
results.plot(y=['algorithm_period_return', ''])
# Out:
# 2012-01-03 00:00:00+00:00    0.0000
# 2012-01-04 00:00:00+00:00   -0.0000
# 2012-01-05 00:00:00+00:00    0.0005
# 2012-01-06 00:00:00+00:00    0.0008
# 2012-01-09 00:00:00+00:00    0.0004
# 2012-01-10 00:00:00+00:00    0.0016
# 2012-01-11 00:00:00+00:00    0.0011
# 2012-01-12 00:00:00+00:00    0.0014
# 2012-01-13 00:00:00+00:00    0.0018
# 2012-01-16 00:00:00+00:00    0.0013
# 2012-01-17 00:00:00+00:00    0.0019
# 2012-01-18 00:00:00+00:00    0.0019
# 2012-01-19 00:00:00+00:00    0.0029
# 2012-01-20 00:00:00+00:00    0.0027
# 2012-01-23 00:00:00+00:00    0.0024
# 2012-01-24 00:00:00+00:00    0.0033
# 2012-01-25 00:00:00+00:00    0.0048
# 2012-01-26 00:00:00+00:00    0.0050
# 2012-01-27 00:00:00+00:00    0.0045
# 2012-01-30 00:00:00+00:00    0.0038
# 2012-01-31 00:00:00+00:00    0.0046
# 2012-02-01 00:00:00+00:00    0.0054
# 2012-02-02 00:00:00+00:00    0.0058
# 2012-02-03 00:00:00+00:00    0.0063
# 2012-02-06 00:00:00+00:00    0.0069
# 2012-02-07 00:00:00+00:00    0.0067
# 2012-02-08 00:00:00+00:00    0.0064
# 2012-02-09 00:00:00+00:00    0.0056
# 2012-02-10 00:00:00+00:00    0.0045
# 2012-02-13 00:00:00+00:00    0.0061
#                               ...
# 2018-11-19 00:00:00+00:00    0.2007
# 2018-11-20 00:00:00+00:00    0.1965
# 2018-11-21 00:00:00+00:00    0.1981
# 2018-11-22 00:00:00+00:00    0.1978
# 2018-11-23 00:00:00+00:00    0.1951
# 2018-11-26 00:00:00+00:00    0.1926
# 2018-11-27 00:00:00+00:00    0.1939
# 2018-11-28 00:00:00+00:00    0.1960
# 2018-11-29 00:00:00+00:00    0.1973
# 2018-11-30 00:00:00+00:00    0.1976
# 2018-12-03 00:00:00+00:00    0.1985
# 2018-12-04 00:00:00+00:00    0.1976
# 2018-12-05 00:00:00+00:00    0.1969
# 2018-12-06 00:00:00+00:00    0.1949
# 2018-12-07 00:00:00+00:00    0.1939
# 2018-12-10 00:00:00+00:00    0.1925
# 2018-12-11 00:00:00+00:00    0.1912
# 2018-12-12 00:00:00+00:00    0.1884
# 2018-12-13 00:00:00+00:00    0.1887
# 2018-12-14 00:00:00+00:00    0.1882
# 2018-12-17 00:00:00+00:00    0.1868
# 2018-12-18 00:00:00+00:00    0.1855
# 2018-12-19 00:00:00+00:00    0.1868
# 2018-12-20 00:00:00+00:00    0.1874
# 2018-12-21 00:00:00+00:00    0.1868
# 2018-12-24 00:00:00+00:00    0.1833
# 2018-12-25 00:00:00+00:00    0.1813
# 2018-12-26 00:00:00+00:00    0.1833
# 2018-12-27 00:00:00+00:00    0.1858
# 2018-12-28 00:00:00+00:00    0.1891
# Name: algorithm_period_return, Length: 1754, dtype: float64
