# %% [markdown]
# ## Long-Short Cross-Sectional Momentum Strategy
#
# - Ranking Period: 6 months
# - Holding Period: 1 months
# - Assets in losers portfolio: 10
# - Assets in winners portfolio: 10
# - Rebalance technique: Equally-weighted

# %%
from zipline.finance.commission import PerDollar
# %matplotlib inline
from datetime import datetime
import pytz
from trading_calendars import get_calendar
from zipline import run_algorithm
from zipline.api import schedule_function
from zipline.utils.events import date_rules, time_rules
from strategies.momentum import Momentum
import pandas as pd

def initialize(context):
    strategy = Momentum(ranking_period=6,
                                holding_period=6,
                                momentum_gap=1,
                                losers_amount=15,
                                winners_amount=15)
    strategy.initialize(context)
    context.strategy = strategy


def rebalance(context, data):
    context.strategy.rebalance(context, data)


def analyze(context, perf: pd.DataFrame) -> None:
    context.strategy.analyze(context, perf)

# %%
start = datetime(2012, 1, 3, 7, 0, 0, tzinfo=pytz.timezone('Europe/Moscow'))
end = datetime(2018, 12, 31, 7, 0, 0, tzinfo=pytz.timezone('Europe/Moscow'))
results = run_algorithm(
    start=start,
    end=end,
    initialize=initialize,
    capital_base=1000000,
    analyze=analyze,
    bundle='database_bundle2',
    trading_calendar=get_calendar('XMOS')
)
# Out:
# Initialized strategy CSMOM_L_S_6_6.pickle at 0.0 seconds
# 2012-02-01 - Last Month Result: -0.97%
# 2012-03-01 - Last Month Result: -1.08%
# 2012-04-02 - Last Month Result: 1.95%
# 2012-05-02 - Last Month Result: 0.55%
# 2012-06-01 - Last Month Result: -0.93%
# 2012-07-02 - Last Month Result: 1.04%
# 2012-08-01 - Last Month Result: 1.00%
# 2012-09-03 - Last Month Result: 0.07%
# 2012-10-01 - Last Month Result: -1.78%
# 2012-11-01 - Last Month Result: 1.55%
# 2012-12-03 - Last Month Result: -0.08%
# 2013-01-08 - Last Month Result: 0.28%
# 2013-02-01 - Last Month Result: -0.72%
# 2013-03-01 - Last Month Result: 0.18%
# 2013-04-01 - Last Month Result: 0.40%
# 2013-05-02 - Last Month Result: 1.10%
# 2013-06-03 - Last Month Result: 1.13%
# 2013-07-01 - Last Month Result: 1.24%
# 2013-08-01 - Last Month Result: -0.22%
# 2013-09-02 - Last Month Result: 0.61%
# 2013-10-01 - Last Month Result: 1.20%
# 2013-11-01 - Last Month Result: 2.31%
# 2013-12-02 - Last Month Result: 2.63%
# 2014-01-06 - Last Month Result: -1.69%
# 2014-02-03 - Last Month Result: -0.51%
# 2014-03-03 - Last Month Result: 1.24%
# 2014-04-01 - Last Month Result: -1.05%
# 2014-05-02 - Last Month Result: 0.41%
# 2014-06-02 - Last Month Result: -2.65%
# 2014-07-01 - Last Month Result: 0.08%
# 2014-08-01 - Last Month Result: 0.96%
# 2014-09-01 - Last Month Result: -0.96%
# 2014-10-01 - Last Month Result: 0.38%
# 2014-11-03 - Last Month Result: 1.19%
td>
#       <td>140</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>1.45</td>
#       <td>2012-07-31</td>
#       <td>2012-08-14</td>
#       <td>2012-08-30</td>
#       <td>23</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.29</td>
#       <td>2012-05-02</td>
#       <td>2012-06-05</td>
#       <td>2012-06-22</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>EZB IR Event</th>
#       <td>-0.04%</td>
#       <td>-0.59%</td>
#       <td>0.44%</td>
#     </tr>
#     <tr>
#       <th>Apr14</th>
#       <td>0.03%</td>
#       <td>-0.20%</td>
#       <td>0.31%</td>
#     </tr>
#     <tr>
#       <th>Oct14</th>
#       <td>0.05%</td>
#       <td>-0.25%</td>
#       <td>0.39%</td>
#     </tr>
#     <tr>
#       <th>Fall2015</th>
#       <td>0.01%</td>
#       <td>-0.47%</td>
#       <td>0.58%</td>
#     </tr>
#     <tr>
#       <th>Recovery</th>
#       <td>0.01%</td>
#       <td>-0.67%</td>
#       <td>0.61%</td>
#     </tr>
#     <tr>
#       <th>New Normal</th>
#       <td>0.01%</td>
#       <td>-3.61%</td>
#       <td>5.23%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 long positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>IRKT</th>
#       <td>2.84%</td>
#     </tr>
#     <tr>
#       <th>TGKBP</th>
#       <td>2.81%</td>
#     </tr>
#     <tr>
#       <th>UNKL</th>
#       <td>2.77%</td>
#     </tr>
#     <tr>
#       <th>SELG</th>
#       <td>2.38%</td>
#     </tr>
#     <tr>
#       <th>MTLRP</th>
#       <td>2.09%</td>
#     </tr>
#     <tr>
#       <th>DVEC</th>
#       <td>2.07%</td>
#     </tr>
#     <tr>
#       <th>CHMK</th>
#       <td>1.89%</td>
#     </tr>
#     <tr>
#       <th>MGTSP</th>
#       <td>1.82%</td>
#     </tr>
#     <tr>
#       <th>MRKV</th>
#       <td>1.81%</td>
#     </tr>
#     <tr>
#       <th>MRKP</th>
#       <td>1.81%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 short positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ROLO</th>
#       <td>-14.95%</td>
#     </tr>
#     <tr>
#       <th>CHEP</th>
#       <td>-3.35%</td>
#     </tr>
#     <tr>
#       <th>GRNT</th>
#       <td>-2.98%</td>
#     </tr>
#     <tr>
#       <th>MTLRP</th>
#       <td>-2.59%</td>
#     </tr>
#     <tr>
#       <th>TGKB</th>
#       <td>-2.56%</td>
#     </tr>
#     <tr>
#       <th>MTLR</th>
#       <td>-2.43%</td>
#     </tr>
#     <tr>
#       <th>RUGR</th>
#       <td>-2.08%</td>
#     </tr>
#     <tr>
#       <th>TGKD</th>
#       <td>-1.95%</td>
#     </tr>
#     <tr>
#       <th>CHMK</th>
#       <td>-1.94%</td>
#     </tr>
#     <tr>
#       <th>LNZL</th>
#       <td>-1.92%</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Top 10 positions of all time</th>
#       <th>max</th>
#     </tr>
#     <tr>
#       <th>sid</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>ROLO</th>
#       <td>14.95%</td>
#     </tr>
#     <tr>
#       <th>CHEP</th>
#       <td>3.35%</td>
#     </tr>
#     <tr>
#       <th>GRNT</th>
#       <td>2.98%</td>
#     </tr>
#     <tr>
#       <th>IRKT</th>
#       <td>2.84%</td>
#     </tr>
#     <tr>
#       <th>TGKBP</th>
#       <td>2.81%</td>
#     </tr>
#     <tr>
#       <th>UNKL</th>
#       <td>2.77%</td>
#     </tr>
#     <tr>
#       <th>MTLRP</th>
#       <td>2.59%</td>
#     </tr>
#     <tr>
#       <th>TGKB</th>
#       <td>2.56%</td>
#     </tr>
#     <tr>
#       <th>MTLR</th>
#       <td>2.43%</td>
#     </tr>
#     <tr>
#       <th>SELG</th>
#       <td>2.38%</td>
#     </tr>
#   </tbody>
# </table>
